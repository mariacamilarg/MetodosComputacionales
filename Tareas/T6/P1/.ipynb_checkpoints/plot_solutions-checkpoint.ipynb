# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Datos
num_graficas=30

#Importando resultados de cazador y presa.
data = loadtxt("resultados.txt")

# %%
xs=data[:,2*1]
ys=data[:,2*1+1]
    
plot(xs,ys)
